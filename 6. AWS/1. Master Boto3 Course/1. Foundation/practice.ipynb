# %%
# %pip install boto3
import boto3

# %% [markdown]
# # Boto3 Client

# %%
s3 = boto3.client(
  's3',
  aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
  aws_secret_access_key="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",
  region_name = "us-east-1"
)


response = s3.list_buckets()
response['Buckets'][0]
# Out:
# {'Name': 'glue-s3-project-sales-data',
#  'CreationDate': datetime.datetime(2025, 11, 12, 19, 47, 44, tzinfo=tzutc()),
#  'BucketArn': 'arn:aws:s3:::glue-s3-project-sales-data'}

# %% [markdown]
# # Boto3 Resourse

# %%
s3 = boto3.resource(
  's3',
  aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
  aws_secret_access_key="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",
  region_name = "us-east-1"
)

for b in s3.buckets.all():
    print(b.name)
# Out:
# glue-s3-project-sales-data
