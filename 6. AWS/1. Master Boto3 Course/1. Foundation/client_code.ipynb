# %% [markdown]
# #BOTO3 CLIENT

# %%
# %pip install boto3

# %%
import boto3

# %%
#configure s3

boto3.client('s3',
             aws_access_key_id = "AKIA6ANVOGWXVQWTDQYF",
             aws_secret_access_key_id = "P/2GPo10idrDHDA0oq98aiwolSSEQqB5N1gJ8vOP",
             aws_region = 'us-east-1'
             )

# %%
import boto3

s3 = boto3.client(
    's3',
    aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
    aws_secret_access_key="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",
    region_name="us-east-1"
)

print(s3.list_buckets())

response = s3.list_buckets()

for bucket in response["Buckets"]:
    print(bucket["Name"])
# Out:
# {'ResponseMetadata': {'RequestId': 'TZW08TMC3TEHQF1N', 'HostId': '3uu7Qt1kmvfsTjrtzV2MGzrfrS68icIVDddpErY36fWxMCqK/qxd0T+qka2hic2xH0r/UhTZCCo=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '3uu7Qt1kmvfsTjrtzV2MGzrfrS68icIVDddpErY36fWxMCqK/qxd0T+qka2hic2xH0r/UhTZCCo=', 'x-amz-request-id': 'TZW08TMC3TEHQF1N', 'date': 'Thu, 13 Nov 2025 20:30:21 GMT', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'Buckets': [{'Name': 'glue-s3-project-sales-data', 'CreationDate': datetime.datetime(2025, 11, 12, 19, 47, 44, tzinfo=tzutc()), 'BucketArn': 'arn:aws:s3:::glue-s3-project-sales-data'}], 'Owner': {'ID': '46b6d35c3d49379f4a60f3bb55d65c0cf5bc0f254b0f9433c8027291367aadd6'}}
# glue-s3-project-sales-data

# %%
import boto3

s3 = boto3.client(
  's3',
  aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
  aws_secret_access_key ="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",
  region_name = "us-east-1"
)

response = s3.list_buckets()
response['Buckets'][0]['Name']
# Out:
# 'glue-s3-project-sales-data'
