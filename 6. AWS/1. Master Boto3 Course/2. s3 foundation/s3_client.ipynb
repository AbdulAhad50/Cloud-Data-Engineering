# %%
# %pip install boto3

# %%
import boto3

s3_client = boto3.client(
  's3',
  aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
  aws_secret_access_key="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",
  region_name="us-east-1"
)

response = s3_client.list_buckets()
response['Buckets'][0]['Name']

s3_client.upload_file('File.txt', response['Buckets'][0]['Name'], 'boto3/File.txt')

# %% [markdown]
# # Add or Put Object in Eixisting File

# %%
s3_client.put_object(
  Bucket=f"{response['Buckets'][0]['Name']}",
  Key="File.txt",
  Body="Put Object Data"
)
# Out:
# {'ResponseMetadata': {'RequestId': 'W68J5R28MA05JCH1',
#   'HostId': 'pjNpm/YH4tNOMROsTztQlfKPuL6n4oo+68etz9N917HTy/crNPBtlz+2J7UWrr4JBI/S0M+oNrY=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'pjNpm/YH4tNOMROsTztQlfKPuL6n4oo+68etz9N917HTy/crNPBtlz+2J7UWrr4JBI/S0M+oNrY=',
#    'x-amz-request-id': 'W68J5R28MA05JCH1',
#    'date': 'Fri, 14 Nov 2025 21:01:25 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"40bfa656116997744434aa8fcdfc0793"',
#    'x-amz-checksum-crc32': 'U7fefA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"40bfa656116997744434aa8fcdfc0793"',
#  'ChecksumCRC32': 'U7fefA==',
#  'ChecksumType': 'FULL_OBJECT',
#  'ServerSideEncryption': 'AES256'}
