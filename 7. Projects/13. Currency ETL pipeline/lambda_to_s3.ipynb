# %%
# %pip install requests
# %pip install pandas
# %pip install boto3

# %%
import requests
import pandas as pd
import boto3
import time
import datetime

# %%
from datetime import datetime, date, timedelta

# Get current date and time
current_datetime = datetime.now()
print(f"Current datetime: {current_datetime}")
# Out:
# Current datetime: 2025-11-21 23:33:01.847499

# %%
url = "https://rest.coinapi.io/v1/exchangerate/USD?apikey=75a21776-9880-47a6-a97b-5271c1512da4&invert=true&output_format=json"

# %%
def currencyExchnageApi():
    response = requests.get(url)
    result = response.json()
    return result

# %%
currencyData = {
  "Date":[],
  "Symbol" : [],
  "Rate":[]
}

# %%
data = currencyExchnageApi()

for item in data:
    if item == "rates":
    #    print(len(data[f"{item}"]))
       for data in data[f"{item}"]:
        #    print(data)
           currencyData['Date'].append(data['time'])
           currencyData['Symbol'].append(data['asset_id_quote'])
           currencyData['Rate'].append(data['rate'])

final_exchange_data = pd.DataFrame(currencyData)
final_exchange_data.to_csv(f'data.csv',index=False)

# %% [markdown]
# # Load File DATA to S3

# %%
s3_client = boto3.client('s3',
                         aws_access_key_id="AKIA6ANVOGWX2MW2F2GQ",
                         aws_secret_access_key="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",
                         region_name="us-east-1"
                         )



s3_client

# %%
buckets = s3_client.list_buckets()

bucket_name = buckets['Buckets'][2]['Name']

# try:
#   s3_client.upload_file('./currency_data.csv', bucket_name , 'input_data/currency/year=2025/currency_data.csv')
#   print('Successfully Upload...')
# finally:
#   print('')

buckets['Buckets'][3]['Name']
# Out:
# 'currency-rate-data'
