# %%
# %pip install boto3

# %%
import boto3


s3_client = boto3.client(
  's3',
  aws_access_key_id="AKIA6ANVOGWXVQWTDQYF",
  aws_secret_access_key="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",
  region_name="us-east-1"
)

# %%
buckets = s3_client.list_buckets()

s3_data_destination = buckets['Buckets'][1]['Name']
s3_client.upload_file('./data/customers-1000.csv',s3_data_destination,'input-data/product/year=2025/customers.csv')
